# %%
import pandas as pd

# %%
ad_feature_mapped = pd.read_csv('data/ad_feature_mapped.csv')
user_feature_final = pd.read_csv('data/user_feature_final.csv')
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
ad_feature_mapped.dtypes
# Out:
# aid               int64
# advertiserId    float64
# campaignId      float64
# creativeId      float64
# creativeSize    float64
# adCategoryId    float64
# productId       float64
# productType     float64
# dtype: object

# %%
user_feature_final.dtypes
# Out:
# uid                     int64
# age                   float64
# gender                float64
# marriageStatus        float64
# education             float64
# consumptionAbility    float64
# LBS                   float64
# ct                    float64
# os                    float64
# carrier               float64
# house                 float64
# interest               object
# kw                     object
# topic                  object
# appId                  object
# dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8798814 entries, 0 to 8798813
# Data columns (total 3 columns):
# aid      int64
# uid      int64
# label    int64
# dtypes: int64(3)
# memory usage: 201.4 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265989 entries, 0 to 2265988
# Data columns (total 2 columns):
# aid    int64
# uid    int64
# dtypes: int64(2)
# memory usage: 34.6 MB

# %%
print('user feature number: ', user_feature_final['uid'].drop_duplicates().count())
print('train uid number: ', train['uid'].drop_duplicates().count())
print('test uid number:  ', test['uid'].drop_duplicates().count())
print('test + train:  ', test['uid'].drop_duplicates().count() + train['uid'].drop_duplicates().count())
# Out:
# user feature number:  11420039
# train uid number:  7883466
# test uid number:   2195951
# test + train:   10079417

# %%
print('ad feature number: ', ad_feature_mapped['aid'].drop_duplicates().count())
print('train aid number: ', train['aid'].drop_duplicates().count())
print('test aid number:  ', test['aid'].drop_duplicates().count())
# Out:
# ad feature number:  173
# train aid number:  173
# test aid number:   173

# %%
ad_feature_mapped.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aid</th>
#       <th>advertiserId</th>
#       <th>campaignId</th>
#       <th>creativeId</th>
#       <th>creativeSize</th>
#       <th>adCategoryId</th>
#       <th>productId</th>
#       <th>productType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>177</td>
#       <td>0.000000</td>
#       <td>0.021898</td>
#       <td>0.982558</td>
#       <td>0.142857</td>
#       <td>0.358974</td>
#       <td>0.00000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2050</td>
#       <td>0.923077</td>
#       <td>1.000000</td>
# ...

# %%
user_feature_final.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uid</th>
#       <th>age</th>
#       <th>gender</th>
#       <th>marriageStatus</th>
#       <th>education</th>
#       <th>consumptionAbility</th>
#       <th>LBS</th>
#       <th>ct</th>
#       <th>os</th>
#       <th>carrier</th>
#       <th>house</th>
#       <th>interest</th>
#       <th>kw</th>
#       <th>topic</th>
#       <th>appId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26325489</td>
#       <td>0.8</td>
#       <td>1.0</td>
#       <td>0.048780</td>
#       <td>1.000000</td>
#       <td>1.0</td>
#       <td>0.952859</td>
#       <td>0.333333</td>
# ...

# %%
train_ad = pd.merge(train, ad_feature_mapped, on='aid')
train_ad.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aid</th>
#       <th>uid</th>
#       <th>label</th>
#       <th>advertiserId</th>
#       <th>campaignId</th>
#       <th>creativeId</th>
#       <th>creativeSize</th>
#       <th>adCategoryId</th>
#       <th>productId</th>
#       <th>productType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>699</td>
#       <td>78508957</td>
#       <td>-1</td>
#       <td>0.089744</td>
#       <td>0.051095</td>
#       <td>0.063953</td>
#       <td>0.142857</td>
#       <td>0.205128</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
train_ad.columns
# Out:
# Index(['aid', 'uid', 'label', 'advertiserId', 'campaignId', 'creativeId',
#        'creativeSize', 'adCategoryId', 'productId', 'productType'],
#       dtype='object')

# %%
train_ad_user = pd.merge(train_ad, user_feature_final, on='uid')
train_ad_user.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aid</th>
#       <th>uid</th>
#       <th>label</th>
#       <th>advertiserId</th>
#       <th>campaignId</th>
#       <th>creativeId</th>
#       <th>creativeSize</th>
#       <th>adCategoryId</th>
#       <th>productId</th>
#       <th>productType</th>
#       <th>...</th>
#       <th>consumptionAbility</th>
#       <th>LBS</th>
#       <th>ct</th>
#       <th>os</th>
#       <th>carrier</th>
#       <th>house</th>
#       <th>interest</th>
#       <th>kw</th>
#       <th>topic</th>
#       <th>appId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>699</td>
# ...

# %%
len(train_ad_user[train_ad_user['aid'] == 1746])
# Out:
# 6886

# %%
train_ad_user.to_csv('data/train_ad_user_all.csv', columns=train_ad_user.columns, index=False)

# %%
test_user = pd.merge(test, user_feature_final, on='uid')
test_user.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aid</th>
#       <th>uid</th>
#       <th>age</th>
#       <th>gender</th>
#       <th>marriageStatus</th>
#       <th>education</th>
#       <th>consumptionAbility</th>
#       <th>LBS</th>
#       <th>ct</th>
#       <th>os</th>
#       <th>carrier</th>
#       <th>house</th>
#       <th>interest</th>
#       <th>kw</th>
#       <th>topic</th>
#       <th>appId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2118</td>
#       <td>64355836</td>
#       <td>0.2</td>
#       <td>0.5</td>
#       <td>0.219512</td>
#       <td>0.857143</td>
#       <td>1.0</td>
# ...

# %%
test_ad_user_all = pd.merge(test_user, ad_feature_mapped, on='aid')
test_ad_user_all.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aid</th>
#       <th>uid</th>
#       <th>age</th>
#       <th>gender</th>
#       <th>marriageStatus</th>
#       <th>education</th>
#       <th>consumptionAbility</th>
#       <th>LBS</th>
#       <th>ct</th>
#       <th>os</th>
#       <th>...</th>
#       <th>kw</th>
#       <th>topic</th>
#       <th>appId</th>
#       <th>advertiserId</th>
#       <th>campaignId</th>
#       <th>creativeId</th>
#       <th>creativeSize</th>
#       <th>adCategoryId</th>
#       <th>productId</th>
#       <th>productType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2118</td>
# ...

# %%
test_ad_user_all.to_csv('data/test_ad_user_all.csv', columns=test_ad_user_all.columns, index=False)

# %%
test_ad_user_all = pd.read_csv('data/test_ad_user_all.csv')

# %%
column = ['aid', 'uid', 
          'advertiserId', 'campaignId', 'creativeId', 'creativeSize', 'adCategoryId', 'productId', 'productType',
          'age', 'gender', 'marriageStatus', 'education', 'consumptionAbility', 'LBS', 'ct', 'os', 'carrier', 'house', 
          'interest', 'kw', 'topic', 'appId']
test_ad_user_all.to_csv('data/test_ad_user_all.csv', columns=column, index=False)
