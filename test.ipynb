# %%
import data_input
import pandas as pd
# Out:
# C:\ProgramData\Anaconda3\envs\tf_gpu\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tr_x = pd.read_csv('data/tr_x.csv')
tr_y = pd.read_csv('data/tr_y.csv')
val_x = pd.read_csv('data/val_x.csv')
val_y = pd.read_csv('data/val_y.csv')

# %%
tr_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7039051 entries, 0 to 7039050
# Data columns (total 21 columns):
# aid                   int64
# uid                   int64
# advertiserId          int64
# campaignId            int64
# creativeId            int64
# creativeSize          int64
# adCategoryId          int64
# productId             int64
# productType           int64
# LBS                   int64
# age                   int64
# carrier               int64
# consumptionAbility    int64
# ct                    int64
# education             int64
# gender                int64
# house                 int64
# marriageStatus        int64
# os                    int64
# embed                 object
# aid_                  int64
# dtypes: int64(20), object(1)
# memory usage: 1.1+ GB

# %%
tr_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7039051 entries, 0 to 7039050
# Data columns (total 1 columns):
# label    int64
# dtypes: int64(1)
# memory usage: 53.7 MB

# %%
val_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759763 entries, 0 to 1759762
# Data columns (total 21 columns):
# aid                   int64
# uid                   int64
# advertiserId          int64
# campaignId            int64
# creativeId            int64
# creativeSize          int64
# adCategoryId          int64
# productId             int64
# productType           int64
# LBS                   int64
# age                   int64
# carrier               int64
# consumptionAbility    int64
# ct                    int64
# education             int64
# gender                int64
# house                 int64
# marriageStatus        int64
# os                    int64
# embed                 object
# aid_                  int64
# dtypes: int64(20), object(1)
# memory usage: 281.9+ MB

# %%
val_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759763 entries, 0 to 1759762
# Data columns (total 1 columns):
# label    int64
# dtypes: int64(1)
# memory usage: 13.4 MB

# %%
tr_x = pd.read_csv('data/tr_x.csv')
tr_y = pd.read_csv('data/tr_y.csv')

tr_base, tr_interest, tr_kw, tr_topic, tr_app = data_input.parse_feature(tr_x)

# %%
tr_base.describe()
# Out:
#        advertiserId    campaignId    creativeId  creativeSize  adCategoryId  \
# count  7.039051e+06  7.039051e+06  7.039051e+06  7.039051e+06  7.039051e+06
# mean   3.313872e+01  1.449072e+02  2.983500e+02  3.946658e+02  4.164619e+02
# std    2.187063e+01  3.982075e+01  5.088283e+01  3.375819e+00  8.736906e+00
# min    0.000000e+00  7.900000e+01  2.170000e+02  3.900000e+02  4.050000e+02
# 25%    1.500000e+01  1.120000e+02  2.540000e+02  3.920000e+02  4.110000e+02
# 50%    2.900000e+01  1.440000e+02  2.910000e+02  3.940000e+02  4.130000e+02
# 75%    5.000000e+01  1.840000e+02  3.450000e+02  3.960000e+02  4.210000e+02
# max    7.800000e+01  2.160000e+02  3.890000e+02  4.040000e+02  4.440000e+02
#
#           productId   productType           age       carrier  \
# count  7.039051e+06  7.039051e+06  7.039051e+06  7.039051e+06
# mean   4.513924e+02  4.793772e+02  4.849614e+02  4.891006e+02
# std    9.394401e+00  1.262183e+00  1.519054e+00  9.619493e-01
# ...

# %%
tr_base.as_matrix()
# Out:
# array([[  74,  183,  252, ...,  708,  949, 1581],
#        [  36,  162,  238, ...,  583, 1414, 1581],
#        [  48,  106,  335, ...,  706, 1311, 1581],
#        ...,
#        [  12,   82,  369, ...,  661,  848, 1582],
#        [  78,  207,  379, ...,  695, 1311, 1581],
#        [  31,  120,  314, ...,  641, 1221, 1581]], dtype=int64)

# %%
tr_app.value_counts()
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
tr_app.describe()
# Out:
# count     7039051
# unique     151114
# top             0
# freq      6855559
# Name: app, dtype: object
