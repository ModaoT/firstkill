# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
auc = pd.read_csv('results/auc.csv')

# %%
auc['train_auc'].plot()
plt.show()

# %%
plt.hist(auc['train_auc'])
# Out:
# (array([  2.,   4.,   9.,  43.,  65., 139., 247., 218., 118.,  15.]),
#  array([0.51762887, 0.55520597, 0.59278308, 0.63036019, 0.66793729,
#         0.7055144 , 0.74309151, 0.78066861, 0.81824572, 0.85582283,
#         0.89339993]),
#  <a list of 10 Patch objects>)

# %%
sub = pd.read_csv('results/submission.csv')

# %%
plt.hist(sub['score'])
# Out:
# (array([1994047.,  184790.,   41844.,   15518.,    9690.,    6565.,
#            4546.,    3424.,    2893.,    2672.]),
#  array([1.5994318e-26, 1.0000000e-01, 2.0000000e-01, 3.0000000e-01,
#         4.0000000e-01, 5.0000000e-01, 6.0000000e-01, 7.0000000e-01,
#         8.0000000e-01, 9.0000000e-01, 1.0000000e+00]),
#  <a list of 10 Patch objects>)

# %%
scores = sub['score']

# %%
pos = scores[scores >= 0.5]
neg = scores[scores < 0.5]

# %%
print(len(pos))
print(len(neg))
# Out:
# 20100
# 2245889

# %%
len(pos) / len(neg)
# Out:
# 0.008949685402974056

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
res = pd.read_csv('results/auc.csv')
res.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>0.780371</th>
#       <th>0.7844151</th>
#       <th>0.4791054870871157</th>
#       <th>0.44798782824002703</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>0.249285</td>
#       <td>0.256827</td>
#       <td>0.518603</td>
#       <td>0.588563</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>100</td>
#       <td>0.225487</td>
#       <td>0.233863</td>
#       <td>0.496280</td>
#       <td>0.554219</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150</td>
#       <td>0.193992</td>
#       <td>0.186848</td>
# ...

# %%
plt.plot(res['train_loss'])
plt.plot(res['train_auc'])
plt.figure()
plt.plot(res['valid_loss'])
plt.plot(res['valid_auc'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\tf_gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'train_loss'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f351bba1426c> in <module>()
# ...

# %%
res['train_auc'].describe()
# Out:
# count    54.000000
# mean      0.693648
# std       0.056602
# min       0.567546
# 25%       0.661956
# 50%       0.687357
# 75%       0.738227
# max       0.816077
# Name: train_auc, dtype: float64

# %%
res['valid_auc'].describe()
# Out:
# count    54.000000
# mean      0.697145
# std       0.060352
# min       0.551095
# 25%       0.662739
# 50%       0.702658
# 75%       0.738956
# max       0.809002
# Name: valid_auc, dtype: float64
