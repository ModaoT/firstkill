# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
auc = pd.read_csv('results/auc.csv')

# %%
auc['train_auc'].plot()
plt.show()

# %%
plt.hist(auc['train_auc'])
# Out:
# (array([  2.,   4.,   9.,  43.,  65., 139., 247., 218., 118.,  15.]),
#  array([0.51762887, 0.55520597, 0.59278308, 0.63036019, 0.66793729,
#         0.7055144 , 0.74309151, 0.78066861, 0.81824572, 0.85582283,
#         0.89339993]),
#  <a list of 10 Patch objects>)

# %%
sub = pd.read_csv('results/submission.csv')

# %%
plt.hist(sub['score'])
# Out:
# (array([1994047.,  184790.,   41844.,   15518.,    9690.,    6565.,
#            4546.,    3424.,    2893.,    2672.]),
#  array([1.5994318e-26, 1.0000000e-01, 2.0000000e-01, 3.0000000e-01,
#         4.0000000e-01, 5.0000000e-01, 6.0000000e-01, 7.0000000e-01,
#         8.0000000e-01, 9.0000000e-01, 1.0000000e+00]),
#  <a list of 10 Patch objects>)

# %%
scores = sub['score']

# %%
pos = scores[scores >= 0.5]
neg = scores[scores < 0.5]

# %%
print(len(pos))
print(len(neg))
# Out:
# 20100
# 2245889

# %%
len(pos) / len(neg)
# Out:
# 0.008949685402974056

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
res1 = pd.read_csv('results/auc_pw1.csv')
res1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>step</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>train_auc</th>
#       <th>valid_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.739781</td>
#       <td>0.740751</td>
#       <td>0.583955</td>
#       <td>0.331747</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>50</td>
#       <td>0.558629</td>
#       <td>0.429565</td>
#       <td>0.462006</td>
#       <td>0.482638</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>100</td>
#       <td>0.205315</td>
#       <td>0.223332</td>
#       <td>0.608189</td>
# ...

# %%
plt.plot(res1['train_loss'])
plt.plot(res1['train_auc'])
plt.figure()
plt.plot(res1['valid_loss'])
plt.plot(res1['valid_auc'])

# %%
res2 = pd.read_csv('results/auc.csv')

# %%
plt.plot(res1['valid_auc'])
plt.plot(res2['valid_auc'])
